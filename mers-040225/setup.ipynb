# %% [markdown]
# # Setup A3FE Runs from FEGrow Output

# %%
import os
from rdkit import Chem
from rdkit.Chem import rdMolAlign

RMSD_FILTER_THRESHOLD = 0.5

# %%
# Get all the pdb files
sdfs = [f for f in os.listdir('input/full_run-MERS/structures') if f.endswith('.sdf')]
# Sort by the number in the filename
sdfs.sort(key=lambda x: int(x.split('.')[0].split('_')[-1]))

# Read in all conformers with RDKit
conformers = {}
for sdf in sdfs:
    mol_num = sdf.split('.')[0].split('_')[-1]
    print(f'Processing {sdf}')

    # Get from sdf, keeping hydrogens
    mols = Chem.SDMolSupplier(f'input/full_run-MERS/structures/{sdf}', removeHs=False)

    # Filter out molecules with low RMSD difference to any other conformer
    filtered_mols = {}
    for i, conf in enumerate(mols):
        rmsds = [rdMolAlign.CalcRMS(conf, filtered_conf) for filtered_conf in filtered_mols.values()]
        if all(rmsd > RMSD_FILTER_THRESHOLD for rmsd in rmsds):
            filtered_mols[i] = conf
        else:
            # Get the conformer with the minimum RMSD
            min_rmsd_idx = rmsds.index(min(rmsds))
            min_rmsd_conf_name = list(filtered_mols.keys())[min_rmsd_idx]
            print(f'{sdf} conformer {i} has a minimum RMSD to conformer {min_rmsd_conf_name} of {min(rmsds)}')

    # If there's only 1 conformer, skip it
    if len(filtered_mols) == 1:
        print(f'Skipping {sdf} because it only has 1 conformer')
        continue

    for i, conf in filtered_mols.items():
        conf_name = f'lig_{mol_num}_{i}'
        conformers[conf_name] = conf
# Out:
# Processing best_conformers_0.sdf
# best_conformers_0.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.02741914520566837
# best_conformers_0.sdf conformer 3 has a minimum RMSD to conformer 2 of 0.0357790840735598
# best_conformers_0.sdf conformer 5 has a minimum RMSD to conformer 4 of 0.017446062001640315
# Processing best_conformers_1.sdf
# best_conformers_1.sdf conformer 8 has a minimum RMSD to conformer 7 of 0.1376199654917876
# Processing best_conformers_2.sdf
# Processing best_conformers_3.sdf
# Processing best_conformers_4.sdf
# Processing best_conformers_5.sdf
# best_conformers_5.sdf conformer 6 has a minimum RMSD to conformer 5 of 0.49179796664890757
# Processing best_conformers_6.sdf
# Processing best_conformers_7.sdf
# best_conformers_7.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.003571660224147461
# best_conformers_7.sdf conformer 3 has a minimum RMSD to conformer 2 of 0.000434958836200937
# best_conformers_7.sdf conformer 5 has a minimum RMSD to conformer 4 of 0.0003676073110465695
# Processing best_conformers_8.sdf
# Processing best_conformers_9.sdf
# Processing best_conformers_10.sdf
# best_conformers_10.sdf conformer 4 has a minimum RMSD to conformer 2 of 0.2719459198688837
# best_conformers_10.sdf conformer 8 has a minimum RMSD to conformer 3 of 0.05306220144530576
# Processing best_conformers_11.sdf
# Processing best_conformers_12.sdf
# best_conformers_12.sdf conformer 3 has a minimum RMSD to conformer 1 of 0.42405825573300576
# best_conformers_12.sdf conformer 4 has a minimum RMSD to conformer 2 of 0.42022911683782443
# best_conformers_12.sdf conformer 5 has a minimum RMSD to conformer 0 of 0.4157930131534609
# best_conformers_12.sdf conformer 7 has a minimum RMSD to conformer 6 of 0.030511246618464816
# Processing best_conformers_13.sdf
# Processing best_conformers_14.sdf
# Processing best_conformers_15.sdf
# Skipping best_conformers_15.sdf because it only has 1 conformer
# Processing best_conformers_16.sdf
# best_conformers_16.sdf conformer 3 has a minimum RMSD to conformer 2 of 0.0006684373647832667
# best_conformers_16.sdf conformer 5 has a minimum RMSD to conformer 4 of 0.00043759497449349515
# Processing best_conformers_17.sdf
# Processing best_conformers_18.sdf
# Processing best_conformers_19.sdf
# best_conformers_19.sdf conformer 3 has a minimum RMSD to conformer 1 of 0.3557389827958091
# Processing best_conformers_20.sdf
# Processing best_conformers_21.sdf
# Processing best_conformers_22.sdf
# Processing best_conformers_23.sdf
# Processing best_conformers_24.sdf
# Processing best_conformers_25.sdf
# Processing best_conformers_26.sdf
# Processing best_conformers_27.sdf
# best_conformers_27.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.0005897678246197036
# best_conformers_27.sdf conformer 2 has a minimum RMSD to conformer 0 of 0.0004662524041201677
# best_conformers_27.sdf conformer 6 has a minimum RMSD to conformer 5 of 0.0005107539184553017
# best_conformers_27.sdf conformer 7 has a minimum RMSD to conformer 5 of 0.000551677284367476
# best_conformers_27.sdf conformer 8 has a minimum RMSD to conformer 5 of 0.0004890096469219989
# best_conformers_27.sdf conformer 9 has a minimum RMSD to conformer 5 of 0.0008075728530877092
# best_conformers_27.sdf conformer 10 has a minimum RMSD to conformer 5 of 0.003489113503954433
# best_conformers_27.sdf conformer 12 has a minimum RMSD to conformer 11 of 0.002048329117576922
# best_conformers_27.sdf conformer 13 has a minimum RMSD to conformer 11 of 0.0020376883748610785
# best_conformers_27.sdf conformer 15 has a minimum RMSD to conformer 14 of 0.0098653984692218
# best_conformers_27.sdf conformer 16 has a minimum RMSD to conformer 14 of 0.01010811125005466
# best_conformers_27.sdf conformer 17 has a minimum RMSD to conformer 14 of 0.009841129309533458
# best_conformers_27.sdf conformer 18 has a minimum RMSD to conformer 14 of 0.009932380072925387
# best_conformers_27.sdf conformer 21 has a minimum RMSD to conformer 20 of 0.0007939992333805976
# best_conformers_27.sdf conformer 22 has a minimum RMSD to conformer 20 of 0.0008075728530873924
# best_conformers_27.sdf conformer 23 has a minimum RMSD to conformer 20 of 0.0008722783759888137
# best_conformers_27.sdf conformer 24 has a minimum RMSD to conformer 20 of 0.001010811125005472
# best_conformers_27.sdf conformer 25 has a minimum RMSD to conformer 11 of 0.06061317119025472
# Processing best_conformers_28.sdf
# Skipping best_conformers_28.sdf because it only has 1 conformer
# Processing best_conformers_29.sdf
# Processing best_conformers_30.sdf
# Processing best_conformers_31.sdf
# Processing best_conformers_32.sdf
# best_conformers_32.sdf conformer 6 has a minimum RMSD to conformer 2 of 0.2941448292177776
# best_conformers_32.sdf conformer 8 has a minimum RMSD to conformer 7 of 0.058379267628918444
# Processing best_conformers_33.sdf
# Processing best_conformers_34.sdf
# Skipping best_conformers_34.sdf because it only has 1 conformer
# Processing best_conformers_35.sdf
# Skipping best_conformers_35.sdf because it only has 1 conformer
# Processing best_conformers_36.sdf
# Processing best_conformers_37.sdf
# best_conformers_37.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.03535946360829981
# best_conformers_37.sdf conformer 3 has a minimum RMSD to conformer 2 of 0.0075498344352707275
# best_conformers_37.sdf conformer 5 has a minimum RMSD to conformer 4 of 0.03264582668581099
# Processing best_conformers_38.sdf
# Processing best_conformers_39.sdf
# Processing best_conformers_40.sdf
# Processing best_conformers_41.sdf
# Processing best_conformers_42.sdf
# best_conformers_42.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.4664204112171766
# Skipping best_conformers_42.sdf because it only has 1 conformer
# Processing best_conformers_43.sdf
# Processing best_conformers_44.sdf
# Processing best_conformers_45.sdf
# Processing best_conformers_46.sdf
# Processing best_conformers_47.sdf
# Processing best_conformers_48.sdf
# Processing best_conformers_49.sdf
# Skipping best_conformers_49.sdf because it only has 1 conformer
# Processing best_conformers_50.sdf
# Processing best_conformers_51.sdf
# Processing best_conformers_52.sdf
# Processing best_conformers_53.sdf
# best_conformers_53.sdf conformer 2 has a minimum RMSD to conformer 1 of 0.15474902177480704
# Processing best_conformers_54.sdf
# Processing best_conformers_55.sdf
# Processing best_conformers_56.sdf
# best_conformers_56.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.0003825460278382015
# best_conformers_56.sdf conformer 3 has a minimum RMSD to conformer 2 of 0.0004938647983249158
# best_conformers_56.sdf conformer 5 has a minimum RMSD to conformer 4 of 0.0011790860453922704
# best_conformers_56.sdf conformer 6 has a minimum RMSD to conformer 4 of 0.0004685212856659747
# best_conformers_56.sdf conformer 7 has a minimum RMSD to conformer 4 of 0.0006246950475542341
# best_conformers_56.sdf conformer 8 has a minimum RMSD to conformer 4 of 0.0014733403229793198
# best_conformers_56.sdf conformer 12 has a minimum RMSD to conformer 11 of 0.0006048583789090001
# best_conformers_56.sdf conformer 13 has a minimum RMSD to conformer 11 of 0.0006246950475543901
# Processing best_conformers_57.sdf
# Processing best_conformers_58.sdf
# Skipping best_conformers_58.sdf because it only has 1 conformer
# Processing best_conformers_59.sdf
# Processing best_conformers_60.sdf
# Processing best_conformers_61.sdf
# Processing best_conformers_62.sdf
# best_conformers_62.sdf conformer 2 has a minimum RMSD to conformer 1 of 0.26337019030797165
# best_conformers_62.sdf conformer 3 has a minimum RMSD to conformer 0 of 0.32280854564719497
# best_conformers_62.sdf conformer 9 has a minimum RMSD to conformer 4 of 0.3829573083256147
# best_conformers_62.sdf conformer 10 has a minimum RMSD to conformer 8 of 0.2734353932571904
# Processing best_conformers_63.sdf
# Processing best_conformers_64.sdf
# Processing best_conformers_65.sdf
# Processing best_conformers_66.sdf
# best_conformers_66.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.04493943915414798
# best_conformers_66.sdf conformer 3 has a minimum RMSD to conformer 2 of 0.03268970818585854
# Processing best_conformers_67.sdf
# Skipping best_conformers_67.sdf because it only has 1 conformer
# Processing best_conformers_68.sdf
# Processing best_conformers_69.sdf
# Processing best_conformers_70.sdf
# Processing best_conformers_71.sdf
# Processing best_conformers_72.sdf
# Processing best_conformers_73.sdf
# best_conformers_73.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.018241436346954777
# best_conformers_73.sdf conformer 3 has a minimum RMSD to conformer 2 of 0.015054069217324577
# best_conformers_73.sdf conformer 5 has a minimum RMSD to conformer 4 of 0.015942418708769255
# Processing best_conformers_74.sdf
# Processing best_conformers_75.sdf
# Processing best_conformers_76.sdf
# best_conformers_76.sdf conformer 3 has a minimum RMSD to conformer 2 of 0.03893858131409147
# Processing best_conformers_77.sdf
# Skipping best_conformers_77.sdf because it only has 1 conformer
# Processing best_conformers_79.sdf
# best_conformers_79.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.045853843895577485
# Skipping best_conformers_79.sdf because it only has 1 conformer
# Processing best_conformers_80.sdf
# Processing best_conformers_81.sdf
# Processing best_conformers_82.sdf
# Processing best_conformers_83.sdf
# best_conformers_83.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.4551698553531662
# Processing best_conformers_84.sdf
# Processing best_conformers_85.sdf
# Processing best_conformers_86.sdf
# Processing best_conformers_87.sdf
# Processing best_conformers_88.sdf
# Processing best_conformers_89.sdf
# Processing best_conformers_90.sdf
# Processing best_conformers_91.sdf
# Processing best_conformers_92.sdf
# best_conformers_92.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.01516294475413724
# best_conformers_92.sdf conformer 3 has a minimum RMSD to conformer 2 of 0.005777800509138972
# best_conformers_92.sdf conformer 4 has a minimum RMSD to conformer 0 of 0.4975621633353753
# best_conformers_92.sdf conformer 7 has a minimum RMSD to conformer 6 of 0.00032616403652648967
# best_conformers_92.sdf conformer 8 has a minimum RMSD to conformer 5 of 0.009896270520391149
# Processing best_conformers_93.sdf
# Skipping best_conformers_93.sdf because it only has 1 conformer
# Processing best_conformers_94.sdf
# Processing best_conformers_95.sdf
# best_conformers_95.sdf conformer 3 has a minimum RMSD to conformer 2 of 0.032300131694200415
# best_conformers_95.sdf conformer 5 has a minimum RMSD to conformer 2 of 0.06670060081628758
# best_conformers_95.sdf conformer 7 has a minimum RMSD to conformer 4 of 0.004196658229890404
# Processing best_conformers_96.sdf

# %%
len(conformers)
# Out:
# 412

# %%
# Get all of the charged ligands
charged_ligands = [mol for mol in conformers if Chem.GetFormalCharge(conformers[mol]) != 0]

# %%
len(charged_ligands)
# Out:
# 97

# %%
charged_ligands
# Out:
# ['lig_2_0',
#  'lig_2_1',
#  'lig_6_0',
#  'lig_6_1',
#  'lig_6_2',
#  'lig_6_3',
#  'lig_6_4',
#  'lig_6_5',
#  'lig_10_0',
#  'lig_10_1',
#  'lig_10_2',
#  'lig_10_3',
#  'lig_10_5',
#  'lig_10_6',
#  'lig_10_7',
#  'lig_10_9',
#  'lig_10_10',
#  'lig_10_11',
#  'lig_10_12',
#  'lig_10_13',
#  'lig_14_0',
#  'lig_14_1',
#  'lig_14_2',
#  'lig_14_3',
#  'lig_14_4',
#  'lig_14_5',
#  'lig_14_6',
#  'lig_14_7',
#  'lig_14_8',
#  'lig_19_0',
#  'lig_19_1',
#  'lig_19_2',
#  'lig_23_0',
#  'lig_23_1',
#  'lig_23_2',
#  'lig_23_3',
#  'lig_24_0',
#  'lig_24_1',
#  'lig_24_2',
#  'lig_24_3',
#  'lig_24_4',
#  'lig_24_5',
#  'lig_29_0',
#  'lig_29_1',
#  'lig_32_0',
#  'lig_32_1',
#  'lig_32_2',
#  'lig_32_3',
#  'lig_32_4',
#  'lig_32_5',
#  'lig_32_7',
#  'lig_32_9',
#  'lig_38_0',
#  'lig_38_1',
#  'lig_38_2',
#  'lig_41_0',
#  'lig_41_1',
#  'lig_53_0',
#  'lig_53_1',
#  'lig_62_0',
#  'lig_62_1',
#  'lig_62_4',
#  'lig_62_5',
#  'lig_62_6',
#  'lig_62_7',
#  'lig_62_8',
#  'lig_64_0',
#  'lig_64_1',
#  'lig_64_2',
#  'lig_64_3',
#  'lig_64_4',
#  'lig_64_5',
#  'lig_64_6',
#  'lig_64_7',
#  'lig_73_0',
#  'lig_73_2',
#  'lig_73_4',
#  'lig_76_0',
#  'lig_76_1',
#  'lig_76_2',
#  'lig_76_4',
#  'lig_76_5',
#  'lig_83_0',
#  'lig_83_2',
#  'lig_83_3',
#  'lig_83_4',
#  'lig_83_5',
#  'lig_83_6',
#  'lig_83_7',
#  'lig_83_8',
#  'lig_83_9',
#  'lig_90_0',
#  'lig_90_1',
#  'lig_90_2',
#  'lig_90_3',
#  'lig_94_0',
#  'lig_94_1']

# %%
# Create directories for each ligand

def create_dir(ligand_name, ligand_rdmol):
    
    # Make the directory
    input_dir = f'{ligand_name}/input'
    os.makedirs(input_dir, exist_ok=False)

    # Create soft links to the run_somd.sh and template_config.cfg files
    os.symlink('../../input/run_somd.sh', f'{input_dir}/run_somd.sh')
    
    # If the ligand is charged, use the charged template
    if ligand_name in charged_ligands:
        os.symlink('../../input/template_config_charged.cfg', f'{input_dir}/template_config.cfg')
    else:
        os.symlink('../../input/template_config.cfg', f'{input_dir}/template_config.cfg')

    # Copy in the SARS structure
    os.symlink(f'../../input/full_run-MERS/protein.pdb', f'{input_dir}/protein.pdb')

    # Write out the ligand as ligand.sdf, with hydrogens
    with Chem.SDWriter(f'{input_dir}/ligand.sdf') as writer:
        writer.write(ligand_rdmol)

for lig_name, lig_rdmol in conformers.items():
    create_dir(lig_name, lig_rdmol)

# %%
# Sort first by the ligand number, then by the conformer number
lig_dirs = [d for d in os.listdir() if "lig" in d]
lig_dirs.sort(key=lambda x: (int(x.split('_')[1]), int(x.split('_')[2])))

# %%
lig_dirs
# Out:
# ['lig_0_0',
#  'lig_0_1',
#  'lig_1_0',
#  'lig_1_1',
#  'lig_2_0',
#  'lig_2_1',
#  'lig_3_0',
#  'lig_3_1',
#  'lig_4_0',
#  'lig_4_1',
#  'lig_4_2',
#  'lig_6_0',
#  'lig_6_2',
#  'lig_6_4',
#  'lig_6_5',
#  'lig_6_6',
#  'lig_6_8',
#  'lig_6_10',
#  'lig_6_11',
#  'lig_7_0',
#  'lig_7_2',
#  'lig_7_4',
#  'lig_7_5',
#  'lig_7_7',
#  'lig_7_9',
#  'lig_7_10',
#  'lig_7_14',
#  'lig_7_17',
#  'lig_8_0',
#  'lig_8_1',
#  'lig_8_2',
#  'lig_8_3',
#  'lig_9_0',
#  'lig_9_1',
#  'lig_9_2',
#  'lig_9_3',
#  'lig_9_4',
#  'lig_9_5',
#  'lig_9_6',
#  'lig_9_7',
#  'lig_10_0',
#  'lig_10_1',
#  'lig_10_2',
#  'lig_10_3',
#  'lig_11_0',
#  'lig_11_4',
#  'lig_11_5',
#  'lig_14_0',
#  'lig_14_1',
#  'lig_15_0',
#  'lig_15_1',
#  'lig_15_2',
#  'lig_15_3',
#  'lig_15_4',
#  'lig_16_0',
#  'lig_16_1',
#  'lig_17_0',
#  'lig_17_1',
#  'lig_17_2',
#  'lig_17_3',
#  'lig_17_4',
#  'lig_17_5',
#  'lig_18_0',
#  'lig_18_1',
#  'lig_18_2',
#  'lig_18_3',
#  'lig_25_0',
#  'lig_25_1',
#  'lig_25_2',
#  'lig_25_3',
#  'lig_25_4',
#  'lig_26_0',
#  'lig_26_1',
#  'lig_26_2',
#  'lig_26_3',
#  'lig_27_0',
#  'lig_27_1',
#  'lig_29_0',
#  'lig_29_1',
#  'lig_29_2',
#  'lig_29_3',
#  'lig_30_0',
#  'lig_30_1',
#  'lig_30_2',
#  'lig_30_3',
#  'lig_31_0',
#  'lig_31_1',
#  'lig_34_0',
#  'lig_34_1',
#  'lig_35_0',
#  'lig_35_1',
#  'lig_35_3',
#  'lig_35_12',
#  'lig_35_24',
#  'lig_37_0',
#  'lig_37_1',
#  'lig_37_2',
#  'lig_39_0',
#  'lig_39_1',
#  'lig_39_2',
#  'lig_39_3',
#  'lig_39_4',
#  'lig_40_0',
#  'lig_40_2',
#  'lig_40_4',
#  'lig_40_6',
#  'lig_41_0',
#  'lig_41_1',
#  'lig_43_0',
#  'lig_43_1',
#  'lig_44_0',
#  'lig_44_1',
#  'lig_44_2',
#  'lig_44_3',
#  'lig_46_0',
#  'lig_46_1',
#  'lig_47_0',
#  'lig_47_1',
#  'lig_47_2',
#  'lig_47_3',
#  'lig_47_4',
#  'lig_48_0',
#  'lig_48_4',
#  'lig_48_6',
#  'lig_48_9',
#  'lig_48_12',
#  'lig_50_0',
#  'lig_50_1',
#  'lig_50_2',
#  'lig_50_3',
#  'lig_51_0',
#  'lig_51_1',
#  'lig_51_2',
#  'lig_51_3',
#  'lig_52_0',
#  'lig_52_1',
#  'lig_52_3',
#  'lig_52_4',
#  'lig_53_0',
#  'lig_53_1',
#  'lig_53_2',
#  'lig_53_3',
#  'lig_54_0',
#  'lig_54_2',
#  'lig_54_4',
#  'lig_54_6',
#  'lig_55_0',
#  'lig_55_1',
#  'lig_55_2',
#  'lig_56_0',
#  'lig_56_2',
#  'lig_59_0',
#  'lig_59_1',
#  'lig_59_2',
#  'lig_59_3',
#  'lig_60_0',
#  'lig_60_1',
#  'lig_60_2',
#  'lig_60_3',
#  'lig_61_0',
#  'lig_61_1',
#  'lig_62_0',
#  'lig_62_2',
#  'lig_62_3',
#  'lig_62_4',
#  'lig_62_5',
#  'lig_62_7',
#  'lig_62_8',
#  'lig_62_9',
#  'lig_62_11',
#  'lig_62_13',
#  'lig_63_0',
#  'lig_63_1',
#  'lig_63_2',
#  'lig_64_0',
#  'lig_64_1',
#  'lig_64_2',
#  'lig_65_0',
#  'lig_65_1',
#  'lig_65_2',
#  'lig_66_0',
#  'lig_66_1',
#  'lig_66_2',
#  'lig_66_3',
#  'lig_67_0',
#  'lig_67_1',
#  'lig_67_2',
#  'lig_70_0',
#  'lig_70_4',
#  'lig_71_0',
#  'lig_71_1',
#  'lig_72_0',
#  'lig_72_1',
#  'lig_72_2',
#  'lig_72_3',
#  'lig_72_4',
#  'lig_72_5',
#  'lig_72_6',
#  'lig_72_7',
#  'lig_72_8',
#  'lig_72_9',
#  'lig_73_0',
#  'lig_73_2',
#  'lig_73_3',
#  'lig_73_5',
#  'lig_73_7',
#  'lig_73_8',
#  'lig_73_10',
#  'lig_74_0',
#  'lig_74_1',
#  'lig_74_2',
#  'lig_76_0',
#  'lig_76_1',
#  'lig_77_0',
#  'lig_77_1',
#  'lig_77_2',
#  'lig_78_0',
#  'lig_78_1',
#  'lig_79_0',
#  'lig_79_1',
#  'lig_79_2',
#  'lig_79_4',
#  'lig_79_10',
#  'lig_79_12',
#  'lig_79_13',
#  'lig_79_16',
#  'lig_79_17',
#  'lig_79_18',
#  'lig_79_19',
#  'lig_79_20',
#  'lig_80_0',
#  'lig_80_1',
#  'lig_81_0',
#  'lig_81_2',
#  'lig_81_4',
#  'lig_81_6',
#  'lig_81_8',
#  'lig_83_0',
#  'lig_83_1',
#  'lig_83_3',
#  'lig_83_5',
#  'lig_83_8',
#  'lig_86_0',
#  'lig_86_1',
#  'lig_86_2',
#  'lig_87_0',
#  'lig_87_1',
#  'lig_87_2',
#  'lig_87_3',
#  'lig_87_4',
#  'lig_88_0',
#  'lig_88_2',
#  'lig_88_3',
#  'lig_88_4',
#  'lig_88_6',
#  'lig_88_10',
#  'lig_88_11',
#  'lig_89_0',
#  'lig_89_4',
#  'lig_89_5',
#  'lig_89_9',
#  'lig_89_13',
#  'lig_92_0',
#  'lig_92_2',
#  'lig_93_0',
#  'lig_93_1',
#  'lig_93_2',
#  'lig_93_3',
#  'lig_95_0',
#  'lig_95_1',
#  'lig_96_0',
#  'lig_96_1',
#  'lig_97_0',
#  'lig_97_1',
#  'lig_97_2']
