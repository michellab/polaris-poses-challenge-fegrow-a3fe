# %% [markdown]
# # Setup A3FE Runs from FEGrow Output

# %%
import os
from rdkit import Chem
from rdkit.Chem import rdMolAlign

RMSD_FILTER_THRESHOLD = 0.5

# %%
# Get all the pdb files
sdfs = [f for f in os.listdir('input/full_run-SARS/structures') if f.endswith('.sdf')]
# Sort by the number in the filename
sdfs.sort(key=lambda x: int(x.split('.')[0].split('_')[-1]))

# Read in all conformers with RDKit
conformers = {}
for sdf in sdfs:
    mol_num = sdf.split('.')[0].split('_')[-1]
    print(f'Processing {sdf}')

    # Get from sdf, keeping hydrogens
    mols = Chem.SDMolSupplier(f'input/full_run-SARS/structures/{sdf}', removeHs=False)

    # Filter out molecules with low RMSD difference to any other conformer
    filtered_mols = {}
    for i, conf in enumerate(mols):
        rmsds = [rdMolAlign.CalcRMS(conf, filtered_conf) for filtered_conf in filtered_mols.values()]
        if all(rmsd > RMSD_FILTER_THRESHOLD for rmsd in rmsds):
            filtered_mols[i] = conf
        else:
            # Get the conformer with the minimum RMSD
            min_rmsd_idx = rmsds.index(min(rmsds))
            min_rmsd_conf_name = list(filtered_mols.keys())[min_rmsd_idx]
            print(f'{sdf} conformer {i} has a minimum RMSD to conformer {min_rmsd_conf_name} of {min(rmsds)}')

    # If there's only 1 conformer, skip it
    if len(filtered_mols) == 1:
        print(f'Skipping {sdf} because it only has 1 conformer')
        continue

    for i, conf in filtered_mols.items():
        conf_name = f'lig_{mol_num}_{i}'
        conformers[conf_name] = conf
# Out:
# Processing best_conformers_0.sdf
# Processing best_conformers_1.sdf
# Processing best_conformers_2.sdf
# Processing best_conformers_3.sdf
# Processing best_conformers_4.sdf
# Processing best_conformers_5.sdf
# Skipping best_conformers_5.sdf because it only has 1 conformer
# Processing best_conformers_6.sdf
# best_conformers_6.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.0003409971697354112
# best_conformers_6.sdf conformer 3 has a minimum RMSD to conformer 2 of 0.0203401310279102
# Processing best_conformers_7.sdf
# best_conformers_7.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.016987294717469945
# best_conformers_7.sdf conformer 3 has a minimum RMSD to conformer 2 of 0.01015672638742873
# best_conformers_7.sdf conformer 6 has a minimum RMSD to conformer 0 of 0.2922543646147368
# best_conformers_7.sdf conformer 8 has a minimum RMSD to conformer 4 of 0.0339133253510127
# best_conformers_7.sdf conformer 13 has a minimum RMSD to conformer 9 of 0.23723109178413113
# best_conformers_7.sdf conformer 16 has a minimum RMSD to conformer 11 of 0.018029647301547064
# best_conformers_7.sdf conformer 17 has a minimum RMSD to conformer 15 of 0.36216881422894476
# Processing best_conformers_8.sdf
# Processing best_conformers_9.sdf
# Processing best_conformers_10.sdf
# Processing best_conformers_11.sdf
# best_conformers_11.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.2584936733590721
# best_conformers_11.sdf conformer 2 has a minimum RMSD to conformer 0 of 0.2640663979002251
# best_conformers_11.sdf conformer 3 has a minimum RMSD to conformer 0 of 0.3724803965758912
# best_conformers_11.sdf conformer 6 has a minimum RMSD to conformer 5 of 0.007179252514479905
# Processing best_conformers_13.sdf
# Skipping best_conformers_13.sdf because it only has 1 conformer
# Processing best_conformers_14.sdf
# Processing best_conformers_15.sdf
# Processing best_conformers_16.sdf
# Processing best_conformers_17.sdf
# Processing best_conformers_18.sdf
# Processing best_conformers_19.sdf
# Skipping best_conformers_19.sdf because it only has 1 conformer
# Processing best_conformers_20.sdf
# Skipping best_conformers_20.sdf because it only has 1 conformer
# Processing best_conformers_21.sdf
# Skipping best_conformers_21.sdf because it only has 1 conformer
# Processing best_conformers_23.sdf
# Skipping best_conformers_23.sdf because it only has 1 conformer
# Processing best_conformers_24.sdf
# Skipping best_conformers_24.sdf because it only has 1 conformer
# Processing best_conformers_25.sdf
# Processing best_conformers_26.sdf
# Processing best_conformers_27.sdf
# Processing best_conformers_28.sdf
# Skipping best_conformers_28.sdf because it only has 1 conformer
# Processing best_conformers_29.sdf
# Processing best_conformers_30.sdf
# Processing best_conformers_31.sdf
# Processing best_conformers_32.sdf
# Skipping best_conformers_32.sdf because it only has 1 conformer
# Processing best_conformers_34.sdf
# Processing best_conformers_35.sdf
# best_conformers_35.sdf conformer 2 has a minimum RMSD to conformer 1 of 0.0025347583711275443
# best_conformers_35.sdf conformer 4 has a minimum RMSD to conformer 3 of 0.01637299606058703
# best_conformers_35.sdf conformer 5 has a minimum RMSD to conformer 3 of 0.016379865689315008
# best_conformers_35.sdf conformer 6 has a minimum RMSD to conformer 3 of 0.016641063667926965
# best_conformers_35.sdf conformer 7 has a minimum RMSD to conformer 3 of 0.01675186556775092
# best_conformers_35.sdf conformer 8 has a minimum RMSD to conformer 3 of 0.016515901428623258
# best_conformers_35.sdf conformer 9 has a minimum RMSD to conformer 3 of 0.016564268773477445
# best_conformers_35.sdf conformer 10 has a minimum RMSD to conformer 3 of 0.01657407614318216
# best_conformers_35.sdf conformer 11 has a minimum RMSD to conformer 3 of 0.01692409524908195
# best_conformers_35.sdf conformer 13 has a minimum RMSD to conformer 12 of 0.0003535533905932898
# best_conformers_35.sdf conformer 14 has a minimum RMSD to conformer 12 of 0.0003535533905933055
# best_conformers_35.sdf conformer 16 has a minimum RMSD to conformer 15 of 0.00038729833462064175
# best_conformers_35.sdf conformer 17 has a minimum RMSD to conformer 15 of 0.0004183300132669254
# best_conformers_35.sdf conformer 18 has a minimum RMSD to conformer 15 of 0.00035355339059324264
# best_conformers_35.sdf conformer 19 has a minimum RMSD to conformer 15 of 0.0004472135954999459
# best_conformers_35.sdf conformer 20 has a minimum RMSD to conformer 15 of 0.003917907604831892
# best_conformers_35.sdf conformer 21 has a minimum RMSD to conformer 15 of 0.00041833001326700497
# best_conformers_35.sdf conformer 22 has a minimum RMSD to conformer 15 of 0.0005000000000000116
# best_conformers_35.sdf conformer 23 has a minimum RMSD to conformer 15 of 0.0004472135954999459
# best_conformers_35.sdf conformer 25 has a minimum RMSD to conformer 24 of 0.0016124515496597665
# best_conformers_35.sdf conformer 26 has a minimum RMSD to conformer 24 of 0.002678619047195982
# best_conformers_35.sdf conformer 27 has a minimum RMSD to conformer 24 of 0.012185031801353613
# best_conformers_35.sdf conformer 28 has a minimum RMSD to conformer 24 of 0.0025884358211091616
# best_conformers_35.sdf conformer 29 has a minimum RMSD to conformer 24 of 0.0030740852297880517
# best_conformers_35.sdf conformer 30 has a minimum RMSD to conformer 24 of 0.0037616485747610094
# best_conformers_35.sdf conformer 31 has a minimum RMSD to conformer 24 of 0.023266929320389575
# Processing best_conformers_36.sdf
# Skipping best_conformers_36.sdf because it only has 1 conformer
# Processing best_conformers_37.sdf
# Processing best_conformers_38.sdf
# Skipping best_conformers_38.sdf because it only has 1 conformer
# Processing best_conformers_39.sdf
# Processing best_conformers_40.sdf
# best_conformers_40.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.002423839928707969
# best_conformers_40.sdf conformer 3 has a minimum RMSD to conformer 2 of 0.0026972207918522307
# best_conformers_40.sdf conformer 5 has a minimum RMSD to conformer 4 of 0.013105342422081076
# best_conformers_40.sdf conformer 7 has a minimum RMSD to conformer 6 of 0.001532970971675471
# Processing best_conformers_41.sdf
# Processing best_conformers_43.sdf
# Processing best_conformers_44.sdf
# Processing best_conformers_45.sdf
# Skipping best_conformers_45.sdf because it only has 1 conformer
# Processing best_conformers_46.sdf
# Processing best_conformers_47.sdf
# Processing best_conformers_48.sdf
# best_conformers_48.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.005107539184552383
# best_conformers_48.sdf conformer 2 has a minimum RMSD to conformer 0 of 0.004674165817229395
# best_conformers_48.sdf conformer 3 has a minimum RMSD to conformer 0 of 0.019103835262562686
# best_conformers_48.sdf conformer 5 has a minimum RMSD to conformer 4 of 0.0005316095330711591
# best_conformers_48.sdf conformer 7 has a minimum RMSD to conformer 6 of 0.0002085144140572023
# best_conformers_48.sdf conformer 8 has a minimum RMSD to conformer 6 of 0.00025537695922748306
# best_conformers_48.sdf conformer 10 has a minimum RMSD to conformer 9 of 0.0004423258684647409
# best_conformers_48.sdf conformer 11 has a minimum RMSD to conformer 9 of 0.00020851441405682033
# best_conformers_48.sdf conformer 13 has a minimum RMSD to conformer 12 of 0.00025537695922773823
# Processing best_conformers_49.sdf
# Skipping best_conformers_49.sdf because it only has 1 conformer
# Processing best_conformers_50.sdf
# Processing best_conformers_51.sdf
# Processing best_conformers_52.sdf
# best_conformers_52.sdf conformer 2 has a minimum RMSD to conformer 1 of 0.018202082009311032
# Processing best_conformers_53.sdf
# Processing best_conformers_54.sdf
# best_conformers_54.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.0006123724356958268
# best_conformers_54.sdf conformer 3 has a minimum RMSD to conformer 2 of 0.002902585054739928
# best_conformers_54.sdf conformer 5 has a minimum RMSD to conformer 4 of 0.00044721359550005765
# best_conformers_54.sdf conformer 7 has a minimum RMSD to conformer 6 of 0.002872281323268985
# Processing best_conformers_55.sdf
# Processing best_conformers_56.sdf
# best_conformers_56.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.019181496932236586
# best_conformers_56.sdf conformer 3 has a minimum RMSD to conformer 2 of 0.005761335127914358
# Processing best_conformers_59.sdf
# best_conformers_59.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.46673893488044615
# Processing best_conformers_60.sdf
# Processing best_conformers_61.sdf
# Processing best_conformers_62.sdf
# best_conformers_62.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.03443307078429645
# best_conformers_62.sdf conformer 6 has a minimum RMSD to conformer 5 of 0.010325387952209667
# best_conformers_62.sdf conformer 10 has a minimum RMSD to conformer 9 of 0.001196586052826163
# best_conformers_62.sdf conformer 12 has a minimum RMSD to conformer 11 of 0.02542144763777241
# Processing best_conformers_63.sdf
# Processing best_conformers_64.sdf
# Processing best_conformers_65.sdf
# Processing best_conformers_66.sdf
# Processing best_conformers_67.sdf
# Processing best_conformers_68.sdf
# Skipping best_conformers_68.sdf because it only has 1 conformer
# Processing best_conformers_69.sdf
# Skipping best_conformers_69.sdf because it only has 1 conformer
# Processing best_conformers_70.sdf
# best_conformers_70.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.012108483993274572
# best_conformers_70.sdf conformer 2 has a minimum RMSD to conformer 0 of 0.06453621523550251
# best_conformers_70.sdf conformer 3 has a minimum RMSD to conformer 0 of 0.04212161878692191
# Processing best_conformers_71.sdf
# Processing best_conformers_72.sdf
# Processing best_conformers_73.sdf
# best_conformers_73.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.005099019513592647
# best_conformers_73.sdf conformer 4 has a minimum RMSD to conformer 3 of 0.013595587519485676
# best_conformers_73.sdf conformer 6 has a minimum RMSD to conformer 5 of 0.0005656854249493602
# best_conformers_73.sdf conformer 9 has a minimum RMSD to conformer 8 of 0.0037920970451716276
# Processing best_conformers_74.sdf
# Processing best_conformers_75.sdf
# Skipping best_conformers_75.sdf because it only has 1 conformer
# Processing best_conformers_76.sdf
# Processing best_conformers_77.sdf
# Processing best_conformers_78.sdf
# Processing best_conformers_79.sdf
# best_conformers_79.sdf conformer 3 has a minimum RMSD to conformer 2 of 0.03689384170231598
# best_conformers_79.sdf conformer 5 has a minimum RMSD to conformer 4 of 0.10691148987207436
# best_conformers_79.sdf conformer 6 has a minimum RMSD to conformer 4 of 0.05178502572065479
# best_conformers_79.sdf conformer 7 has a minimum RMSD to conformer 2 of 0.031190098143837476
# best_conformers_79.sdf conformer 8 has a minimum RMSD to conformer 0 of 0.3239779827910121
# best_conformers_79.sdf conformer 9 has a minimum RMSD to conformer 0 of 0.2891497881721513
# best_conformers_79.sdf conformer 11 has a minimum RMSD to conformer 10 of 0.0126015872016188
# best_conformers_79.sdf conformer 14 has a minimum RMSD to conformer 10 of 0.3293779996700854
# best_conformers_79.sdf conformer 15 has a minimum RMSD to conformer 13 of 0.03450603811895337
# Processing best_conformers_80.sdf
# Processing best_conformers_81.sdf
# best_conformers_81.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.009458975749108508
# best_conformers_81.sdf conformer 3 has a minimum RMSD to conformer 2 of 0.030864848758561412
# best_conformers_81.sdf conformer 5 has a minimum RMSD to conformer 4 of 0.0004409585518442737
# best_conformers_81.sdf conformer 7 has a minimum RMSD to conformer 6 of 0.0010540925533895507
# best_conformers_81.sdf conformer 9 has a minimum RMSD to conformer 8 of 0.0004714045207909536
# Processing best_conformers_82.sdf
# Skipping best_conformers_82.sdf because it only has 1 conformer
# Processing best_conformers_83.sdf
# best_conformers_83.sdf conformer 2 has a minimum RMSD to conformer 1 of 0.235786841835181
# best_conformers_83.sdf conformer 4 has a minimum RMSD to conformer 3 of 0.0004890096469215548
# best_conformers_83.sdf conformer 6 has a minimum RMSD to conformer 5 of 0.000920774721067401
# best_conformers_83.sdf conformer 7 has a minimum RMSD to conformer 0 of 0.24471767228877186
# best_conformers_83.sdf conformer 9 has a minimum RMSD to conformer 8 of 0.004410954742358233
# Processing best_conformers_84.sdf
# Skipping best_conformers_84.sdf because it only has 1 conformer
# Processing best_conformers_85.sdf
# Skipping best_conformers_85.sdf because it only has 1 conformer
# Processing best_conformers_86.sdf
# Processing best_conformers_87.sdf
# Processing best_conformers_88.sdf
# best_conformers_88.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.0008514693182963567
# best_conformers_88.sdf conformer 5 has a minimum RMSD to conformer 4 of 0.0005477225575052984
# best_conformers_88.sdf conformer 7 has a minimum RMSD to conformer 6 of 0.44483078243305063
# best_conformers_88.sdf conformer 8 has a minimum RMSD to conformer 4 of 0.44958175007444395
# best_conformers_88.sdf conformer 9 has a minimum RMSD to conformer 4 of 0.44949963848706237
# best_conformers_88.sdf conformer 12 has a minimum RMSD to conformer 11 of 0.0004183300132672571
# best_conformers_88.sdf conformer 13 has a minimum RMSD to conformer 6 of 0.4485814307347109
# Processing best_conformers_89.sdf
# best_conformers_89.sdf conformer 1 has a minimum RMSD to conformer 0 of 0.010399016053633262
# best_conformers_89.sdf conformer 2 has a minimum RMSD to conformer 0 of 0.010490305602217134
# best_conformers_89.sdf conformer 3 has a minimum RMSD to conformer 0 of 0.009819297564040116
# best_conformers_89.sdf conformer 6 has a minimum RMSD to conformer 5 of 0.0
# best_conformers_89.sdf conformer 7 has a minimum RMSD to conformer 5 of 0.00040347329239290725
# best_conformers_89.sdf conformer 8 has a minimum RMSD to conformer 5 of 0.0003049971406651673
# best_conformers_89.sdf conformer 10 has a minimum RMSD to conformer 9 of 0.01236743661281891
# best_conformers_89.sdf conformer 11 has a minimum RMSD to conformer 9 of 0.005697816799360117
# best_conformers_89.sdf conformer 12 has a minimum RMSD to conformer 9 of 0.005548936625554254
# Processing best_conformers_90.sdf
# Skipping best_conformers_90.sdf because it only has 1 conformer
# Processing best_conformers_91.sdf
# Skipping best_conformers_91.sdf because it only has 1 conformer
# Processing best_conformers_92.sdf
# Processing best_conformers_93.sdf
# Processing best_conformers_95.sdf
# Processing best_conformers_96.sdf
# Processing best_conformers_97.sdf

# %%
len(conformers)
# Out:
# 286

# %%
# Get all of the +1 ligands
positive_1_ligs = [mol for mol in conformers if Chem.GetFormalCharge(conformers[mol]) == 1]
positive_1_ligs
# Out:
# ['lig_10_0',
#  'lig_10_1',
#  'lig_10_2',
#  'lig_10_3',
#  'lig_14_0',
#  'lig_14_1',
#  'lig_25_0',
#  'lig_25_1',
#  'lig_25_2',
#  'lig_25_3',
#  'lig_25_4',
#  'lig_27_0',
#  'lig_27_1',
#  'lig_27_2',
#  'lig_47_0',
#  'lig_47_1',
#  'lig_47_2',
#  'lig_47_3',
#  'lig_47_4',
#  'lig_55_0',
#  'lig_55_1',
#  'lig_55_2',
#  'lig_76_0',
#  'lig_76_1']

# %%
# Get all of the charged ligands
charged_ligands = [mol for mol in conformers if Chem.GetFormalCharge(conformers[mol]) != 0]

# %%
charged_ligands
# Out:
# ['lig_10_0',
#  'lig_10_1',
#  'lig_10_2',
#  'lig_10_3',
#  'lig_14_0',
#  'lig_14_1',
#  'lig_17_0',
#  'lig_17_1',
#  'lig_17_2',
#  'lig_17_3',
#  'lig_17_4',
#  'lig_17_5',
#  'lig_25_0',
#  'lig_25_1',
#  'lig_25_2',
#  'lig_25_3',
#  'lig_25_4',
#  'lig_27_0',
#  'lig_27_1',
#  'lig_27_2',
#  'lig_39_0',
#  'lig_39_1',
#  'lig_39_2',
#  'lig_39_3',
#  'lig_39_4',
#  'lig_47_0',
#  'lig_47_1',
#  'lig_47_2',
#  'lig_47_3',
#  'lig_47_4',
#  'lig_55_0',
#  'lig_55_1',
#  'lig_55_2',
#  'lig_59_0',
#  'lig_59_2',
#  'lig_59_3',
#  'lig_76_0',
#  'lig_76_1']

# %%
# Create directories for each ligand

def create_dir(ligand_name, ligand_rdmol):
    
    # Make the directory
    input_dir = f'{ligand_name}/input'
    os.makedirs(input_dir, exist_ok=False)

    # Create soft links to the run_somd.sh and template_config.cfg files
    os.symlink('../../input/run_somd.sh', f'{input_dir}/run_somd.sh')

    # If the ligand is charged, use the charged template
    if ligand_name in charged_ligands:
        os.symlink('../../input/template_config_charged.cfg', f'{input_dir}/template_config.cfg')
    else:
        os.symlink('../../input/template_config.cfg', f'{input_dir}/template_config.cfg')

    # Copy in the SARS structure
    os.symlink(f'../../input/full_run-SARS/sars_sanitised_for_amber.pdb', f'{input_dir}/protein.pdb')

    # Write out the ligand as ligand.sdf, with hydrogens
    with Chem.SDWriter(f'{input_dir}/ligand.sdf') as writer:
        writer.write(ligand_rdmol)

for i, lig_name, lig_rdmol in conformers.items():
    create_dir(lig_name, lig_rdmol)

# %%
# Sort first by the ligand number, then by the conformer number
lig_dirs = [d for d in os.listdir() if "lig" in d]
lig_dirs.sort(key=lambda x: (int(x.split('_')[1]), int(x.split('_')[2])))

# %%
for i, lig_dir in enumerate(lig_dirs):
    print(f'{i}: {lig_dir}')
# Out:
# 0: lig_0_0
# 1: lig_0_1
# 2: lig_1_0
# 3: lig_1_1
# 4: lig_2_0
# 5: lig_2_1
# 6: lig_3_0
# 7: lig_3_1
# 8: lig_3_2
# 9: lig_4_0
# 10: lig_4_1
# 11: lig_4_2
# 12: lig_6_0
# 13: lig_6_2
# 14: lig_6_4
# 15: lig_6_5
# 16: lig_6_6
# 17: lig_6_7
# 18: lig_6_8
# 19: lig_6_9
# 20: lig_6_10
# 21: lig_6_11
# 22: lig_7_0
# 23: lig_7_2
# 24: lig_7_4
# 25: lig_7_5
# 26: lig_7_7
# 27: lig_7_9
# 28: lig_7_10
# 29: lig_7_11
# 30: lig_7_12
# 31: lig_7_14
# 32: lig_7_15
# 33: lig_8_0
# 34: lig_8_1
# 35: lig_8_2
# 36: lig_8_3
# 37: lig_9_0
# 38: lig_9_1
# 39: lig_9_2
# 40: lig_9_3
# 41: lig_9_4
# 42: lig_9_5
# 43: lig_9_6
# 44: lig_9_7
# 45: lig_10_0
# 46: lig_10_1
# 47: lig_10_2
# 48: lig_10_3
# 49: lig_11_0
# 50: lig_11_4
# 51: lig_11_5
# 52: lig_14_0
# 53: lig_14_1
# 54: lig_15_0
# 55: lig_15_1
# 56: lig_15_2
# 57: lig_15_3
# 58: lig_15_4
# 59: lig_16_0
# 60: lig_16_1
# 61: lig_17_0
# 62: lig_17_1
# 63: lig_17_2
# 64: lig_17_3
# 65: lig_17_4
# 66: lig_17_5
# 67: lig_18_0
# 68: lig_18_1
# 69: lig_18_2
# 70: lig_18_3
# 71: lig_25_0
# 72: lig_25_1
# 73: lig_25_2
# 74: lig_25_3
# 75: lig_25_4
# 76: lig_26_0
# 77: lig_26_1
# 78: lig_26_2
# 79: lig_26_3
# 80: lig_27_0
# 81: lig_27_1
# 82: lig_27_2
# 83: lig_29_0
# 84: lig_29_1
# 85: lig_29_2
# 86: lig_29_3
# 87: lig_30_0
# 88: lig_30_1
# 89: lig_30_2
# 90: lig_30_3
# 91: lig_31_0
# 92: lig_31_1
# 93: lig_34_0
# 94: lig_34_1
# 95: lig_34_2
# 96: lig_35_0
# 97: lig_35_1
# 98: lig_35_3
# 99: lig_35_12
# 100: lig_35_15
# 101: lig_35_24
# 102: lig_37_0
# 103: lig_37_1
# 104: lig_37_2
# 105: lig_39_0
# 106: lig_39_1
# 107: lig_39_2
# 108: lig_39_3
# 109: lig_39_4
# 110: lig_40_0
# 111: lig_40_2
# 112: lig_40_4
# 113: lig_40_6
# 114: lig_41_0
# 115: lig_41_1
# 116: lig_43_0
# 117: lig_43_1
# 118: lig_44_0
# 119: lig_44_1
# 120: lig_44_2
# 121: lig_44_3
# 122: lig_46_0
# 123: lig_46_1
# 124: lig_47_0
# 125: lig_47_1
# 126: lig_47_2
# 127: lig_47_3
# 128: lig_47_4
# 129: lig_48_0
# 130: lig_48_4
# 131: lig_48_6
# 132: lig_48_9
# 133: lig_48_12
# 134: lig_50_0
# 135: lig_50_1
# 136: lig_50_2
# 137: lig_50_3
# 138: lig_51_0
# 139: lig_51_1
# 140: lig_51_2
# 141: lig_51_3
# 142: lig_52_0
# 143: lig_52_1
# 144: lig_52_3
# 145: lig_52_4
# 146: lig_53_0
# 147: lig_53_1
# 148: lig_53_2
# 149: lig_53_3
# 150: lig_54_0
# 151: lig_54_2
# 152: lig_54_4
# 153: lig_54_6
# 154: lig_55_0
# 155: lig_55_1
# 156: lig_55_2
# 157: lig_56_0
# 158: lig_56_2
# 159: lig_59_0
# 160: lig_59_2
# 161: lig_59_3
# 162: lig_60_0
# 163: lig_60_1
# 164: lig_60_2
# 165: lig_60_3
# 166: lig_61_0
# 167: lig_61_1
# 168: lig_62_0
# 169: lig_62_2
# 170: lig_62_3
# 171: lig_62_4
# 172: lig_62_5
# 173: lig_62_7
# 174: lig_62_8
# 175: lig_62_9
# 176: lig_62_11
# 177: lig_62_13
# 178: lig_62_14
# 179: lig_63_0
# 180: lig_63_1
# 181: lig_63_2
# 182: lig_64_0
# 183: lig_64_1
# 184: lig_64_2
# 185: lig_65_0
# 186: lig_65_1
# 187: lig_65_2
# 188: lig_66_0
# 189: lig_66_1
# 190: lig_66_2
# 191: lig_66_3
# 192: lig_67_0
# 193: lig_67_1
# 194: lig_67_2
# 195: lig_70_0
# 196: lig_70_4
# 197: lig_71_0
# 198: lig_71_1
# 199: lig_72_0
# 200: lig_72_1
# 201: lig_72_2
# 202: lig_72_3
# 203: lig_72_4
# 204: lig_72_5
# 205: lig_72_6
# 206: lig_72_7
# 207: lig_72_8
# 208: lig_72_9
# 209: lig_73_0
# 210: lig_73_2
# 211: lig_73_3
# 212: lig_73_5
# 213: lig_73_7
# 214: lig_73_8
# 215: lig_73_10
# 216: lig_74_0
# 217: lig_74_1
# 218: lig_74_2
# 219: lig_76_0
# 220: lig_76_1
# 221: lig_77_0
# 222: lig_77_1
# 223: lig_77_2
# 224: lig_78_0
# 225: lig_78_1
# 226: lig_79_0
# 227: lig_79_1
# 228: lig_79_2
# 229: lig_79_4
# 230: lig_79_10
# 231: lig_79_12
# 232: lig_79_13
# 233: lig_79_16
# 234: lig_79_17
# 235: lig_79_18
# 236: lig_79_19
# 237: lig_79_20
# 238: lig_80_0
# 239: lig_80_1
# 240: lig_81_0
# 241: lig_81_2
# 242: lig_81_4
# 243: lig_81_6
# 244: lig_81_8
# 245: lig_83_0
# 246: lig_83_1
# 247: lig_83_3
# 248: lig_83_5
# 249: lig_83_8
# 250: lig_83_10
# 251: lig_86_0
# 252: lig_86_1
# 253: lig_86_2
# 254: lig_87_0
# 255: lig_87_1
# 256: lig_87_2
# 257: lig_87_3
# 258: lig_87_4
# 259: lig_88_0
# 260: lig_88_2
# 261: lig_88_3
# 262: lig_88_4
# 263: lig_88_6
# 264: lig_88_10
# 265: lig_88_11
# 266: lig_89_0
# 267: lig_89_4
# 268: lig_89_5
# 269: lig_89_9
# 270: lig_89_13
# 271: lig_92_0
# 272: lig_92_1
# 273: lig_92_2
# 274: lig_93_0
# 275: lig_93_1
# 276: lig_93_2
# 277: lig_93_3
# 278: lig_95_0
# 279: lig_95_1
# 280: lig_96_0
# 281: lig_96_1
# 282: lig_96_2
# 283: lig_97_0
# 284: lig_97_1
# 285: lig_97_2
